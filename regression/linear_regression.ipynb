# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pylab as plt

# %%
dataset=pd.read_csv(r'R:\aiml\Machine_Learning\regression\house_prices_dataset.csv')
pd.DataFrame(dataset)
# Out:
#      HouseSize_sqft  Bedrooms  Bathrooms  HouseAge  LocationScore   Price
# 0              3674         4          2        22              1  576217
# 1              1360         4          3        15              5  266435
# 2              1794         3          3        24              7  315334
# 3              1630         2          2         6              6  305828
# 4              1595         4          3        12              1  277096
# ..              ...       ...        ...       ...            ...     ...
# 195            3560         1          3        12              6  570097
# 196            3193         4          1         0              2  520345
# 197            1295         3          3         1              4  248991
# 198            1551         4          1         8              4  302006
# 199            2143         2          1         2              6  367146
#
# [200 rows x 6 columns]

# %%
x=dataset.iloc[:,:-1]
y=dataset["Price"]

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
prediction=model.predict([[3444,3,1,25,4]])
# Out:
# c:\Users\layap\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
prediction[0]
# Out:
# 546201.2650667243

# %%
X=dataset['HouseSize_sqft']
Y=dataset["Price"]

# %% [markdown]
# # **testing**

# %%
import seaborn as sns
import numpy as np

# %%
X=np.array(dataset['HouseSize_sqft']).reshape(-1,1)
Y=np.array(dataset["Price"]).reshape(-1,1)
X.shape
# Out:
# (200, 1)

# %%
model2=LinearRegression()
model2.fit(X,Y)
# Out:
# LinearRegression()

# %%
plt.plot(X,Y,color='blue')
plt.plot(X,model2.predict(X),color='red')
